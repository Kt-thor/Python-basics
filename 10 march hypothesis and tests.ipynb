# %% [markdown]
# Q1. What is Estimation Statistics? Explain point estimate and interval estimate.
#
# Obserevd numerical value used to estimate an unknown population parameter.
# Point estimate gives single numerical value used to estimate unknown population parameter.
# Eg. Sample mean is a point estimate of population mean.
# Internal estimate is the range of values that estimate unknown population parameter also called as comfidence interval.

# %% [markdown]
# Q2. Write a Python function to estimate the population mean using a sample mean and standard
# deviation.

# %%
import math
def population_mean(sample_mean,std,sample_size):
    if sample_size <= 1:
        return "Invalid sample size"
    else:
        t_value = 2.048
        standard_error = std / math.sqrt(sample_size)
        margin_of_error = t_value * std

        population_mean_lower = sample_mean - margin_of_error
        population_mean_upper = sample_mean + margin_of_error

        return (population_mean_lower,population_mean_upper)
    
population_mean(10,1,20)
# Out:
# (7.952, 12.048)

# %% [markdown]
# Q3: What is Hypothesis testing? Why is it used? State the importance of Hypothesis testing.

# %% [markdown]
# Hypothesis testing is a statistical method used to evaluate two opposing hypotheses about a population parameter. The two hypotheses are called the null hypothesis and the alternative hypothesis. The null hypothesis is the default hypothesis that there is no significant difference between a sample statistic and the population parameter. The alternative hypothesis is the opposite of the null hypothesis and is used to test whether a sample statistic differs significantly from the population parameter.
#
# The importance of hypothesis testing lies in its ability to provide a systematic and objective approach to making decisions based on data. It allows researchers to draw conclusions about population parameters from sample statistics and to test the validity of scientific theories. Hypothesis testing also helps to avoid making incorrect conclusions based on anecdotal evidence or intuition, and it provides a way to quantify the level of uncertainty in the conclusions drawn from the data.
#
# Hypothesis testing is used in various fields to make decisions based on empirical data. It is often used to test scientific hypotheses, validate theories, and evaluate the effectiveness of treatments or interventions. Hypothesis testing is also used in quality control, marketing research, and other fields where decisions need to be made based on empirical data.

# %% [markdown]
# Q4. Create a hypothesis that states whether the average weight of male college students is greater than
# the average weight of female college students.

# %% [markdown]
# H0 =>  average weight of male college > avrage weight of female college
#
# H1 =>  average weight of male college <= avrage weight of female college

# %% [markdown]
# Q5. Write a Python script to conduct a hypothesis test on the difference between two population means,
# given a sample from each population.

# %%
import numpy as np
import scipy.stats as stats

# Set the significance level
alpha = 0.05

# Define the sample data
sample1 = [1, 2, 3, 4, 5]
sample2 = [6, 7, 8, 9, 10]

# Calculate the sample means and standard deviations
mean1 = np.mean(sample1)
mean2 = np.mean(sample2)
std1 = np.std(sample1, ddof=1)
std2 = np.std(sample2, ddof=1)

# Calculate the standard error of the difference between the means
se = np.sqrt((std1**2)/len(sample1) + (std2**2)/len(sample2))

# Calculate the t-statistic
t = (mean1 - mean2) / se

# Calculate the degrees of freedom
df = len(sample1) + len(sample2) - 2

# Calculate the p-value
p = 2 * (1 - stats.t.cdf(abs(t), df))

# Compare the p-value to the significance level
if p < alpha:
    print("Reject the null hypothesis")
else:
    print("Fail to reject the null hypothesis")
# Out:
# Reject the null hypothesis

# %% [markdown]
# Q6: What is a null and alternative hypothesis? Give some examples.
#
# In hypothesis testing, we start with two opposing hypotheses: the null hypothesis and the alternative hypothesis. The null hypothesis is the default hypothesis, which assumes that there is no significant difference between a sample statistic and the population parameter. The alternative hypothesis is the opposite of the null hypothesis and is used to test whether a sample statistic differs significantly from the population parameter. In other words, the alternative hypothesis is what we are trying to prove in hypothesis testing.
#
# Here are some examples of null and alternative hypotheses:
#
# Example: A company claims that their new product increases sales by 20%.
#
# Null hypothesis: The new product does not increase sales by 20%.
#
# Alternative hypothesis: The new product does increase sales by 20%.
#
# Example: A scientist wants to test whether a new drug reduces blood pressure.
#
# Null hypothesis: The new drug does not reduce blood pressure.
#
# Alternative hypothesis: The new drug does reduce blood pressure.
#
# Example: A researcher wants to test whether there is a significant difference in the mean income of two different groups.
#
# Null hypothesis: There is no significant difference in the mean income of the two groups.
#
# Alternative hypothesis: There is a significant difference in the mean income of the two groups.

# %% [markdown]
# Q7: Write down the steps involved in hypothesis testing.

# %% [markdown]
# steps:
#
#     1 : Assume null hypothesis
#
#     2 : Assume alternate hypothesis
#
#     3 : statistical analysis
#
#     4 : Decision makeing

# %% [markdown]
# Q8. Define p-value and explain its significance in hypothesis testing.
#
# In hypothesis testing, the p-value is the probability of obtaining a test statistic as extreme or more extreme than the observed value, assuming that the null hypothesis is true. In other words, it is the probability of observing a result as extreme as, or more extreme than, the observed data, given that the null hypothesis is true.
#
# The p-value is used to determine the strength of the evidence against the null hypothesis. A small p-value (typically less than the chosen significance level) indicates that the observed data is unlikely to have occurred by chance alone, and provides evidence to reject the null hypothesis. A large p-value, on the other hand, indicates that the observed data is likely to have occurred by chance alone, and provides no evidence to reject the null hypothesis.

# %% [markdown]
# Q9. Generate a Student's t-distribution plot using Python's matplotlib library, with the degrees of freedom
# parameter set to 10.

# %%
import numpy as np
import matplotlib.pyplot as plt
from scipy.stats import t

# %%
df = 10
x = np.linspace(-8,8,50)
y = t.pdf(x,df)


plt.plot(x, y)
plt.title("Student's t-distribution with df = 10")
plt.xlabel('x')
plt.ylabel('pdf')
plt.show()

# %% [markdown]
# Q10. Write a Python program to calculate the two-sample t-test for independent samples, given two
# random samples of equal size and a null hypothesis that the population means are equal.

# %%
import numpy as np
import scipy.stats as stats

alpha = 0.05

sample1 = np.random.rand(10) 
sample2 = np.random.rand(10)

# %%
mean1 = np.mean(sample1)
mean2 = np.mean(sample2)

# %%
std1 = np.std(sample1, ddof=1)
std2 = np.std(sample2, ddof=1)

# %%
# Calculate the standard error of the difference between the means
se = np.sqrt((std1**2)/len(sample1) + (std2**2)/len(sample2))

# %%
# Calculate the t-statistic
t = (mean1 - mean2) / se

# Calculate the degrees of freedom
df = len(sample1) + len(sample2) - 2

# Calculate the p-value
p = 2 * (1 - stats.t.cdf(abs(t), df))

# Compare the p-value to the significance level
if p < alpha:
    print("Reject the null hypothesis")
else:
    print("Fail to reject the null hypothesis")
# Out:
# Fail to reject the null hypothesis

# %% [markdown]
# Q11: What is Student’s t distribution? When to use the t-Distribution.
#
# The t-distribution is often used in statistical inference, specifically when conducting hypothesis tests and constructing confidence intervals for the population mean. It is also used when the standard deviation of the population is unknown and is estimated using the sample standard deviation.
#
# Student's t-distribution, also known as the t-distribution, is a probability distribution that is used to model the behavior of sample means when the population variance is unknown and the sample size is small (typically less than 30). The t-distribution is similar to the normal distribution in shape, but has heavier tails, which means that it has a higher probability of producing values that are farther from the mean than the normal distribution.

# %% [markdown]
# Q12: What is t-statistic? State the formula for t-statistic.
#
# The t-statistic is a measure of the difference between the sample mean and the hypothesized population mean, in units of the standard error. It is used to test hypotheses about the population mean, when the population standard deviation is unknown.
#
# The formula for the t-statistic is:
#
# t = (x̄ - μ) / (s / sqrt(n))
#
# where:
#
# x̄ is the sample mean
#
# μ is the hypothesized population mean
#
# s is the sample standard deviation
#
# n is the sample size

# %% [markdown]
# Q13. A coffee shop owner wants to estimate the average daily revenue for their shop. They take a random
# sample of 50 days and find the sample mean revenue to be $500   with  a  standard  deviation  of   $50.
# Estimate the population mean revenue with a 95% confidence interval.

# %% [markdown]
# [IMG_20230314_164409748.jpg](attachment:e8307792-9e71-4107-9089-d8170cb9b14b.jpg)

# %%
Q14. A researcher hypothesizes that a new drug will decrease blood pressure by 10 mmHg. They conduct a
clinical trial with 100 patients and find that the sample mean decrease in blood pressure is 8 mmHg with a
standard deviation of 3 mmHg. Test the hypothesis with a significance level of 0.05.

# %% [markdown]
# Q15. An electronics company produces a certain type of product with a mean weight of 5 pounds and a
# standard deviation of 0.5 pounds. A random sample of 25 products is taken, and the sample mean weight
# is found to be 4.8 pounds. Test the hypothesis that the true mean weight of the products is less than 5
# pounds with a significance level of 0.01.

# %% [markdown]
# ![IMG_20230314_164420377.jpg](attachment:039c4b5d-75dd-44bd-95a2-198bd3fce4f5.jpg)

# %% [markdown]
# Q16. Two groups of students are given different study materials to prepare for a test. The first group (n1 =
# 30) has a mean score of 80 with a standard deviation of 10, and the second group (n2 = 40) has a mean
# score of 75 with a standard deviation of 8. Test the hypothesis that the population means for the two
# groups are equal with a significance level of 0.01.

# %% [markdown]
# Q17. A marketing company wants to estimate the average number of ads watched by viewers during a TV
# program. They take a random sample of 50 viewers and find that the sample mean is 4 with a standard
# deviation of 1.5. Estimate the population mean with a 99% confidence interval.
